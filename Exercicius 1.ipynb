# %% [markdown]
# <a href="https://colab.research.google.com/github/Murilo-Hinckel/FIA/blob/main/Exercicius%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 1

# %%
print( "Good bye world")
# Out:
# Good bye world

# %%
def createPrint():
  print(" Olá")

for i in range(9,1,1):
  createPrint

# %% [markdown]
# Aula 2

# %%
# !pip install math
# Out:
# ERROR: Could not find a version that satisfies the requirement math (from versions: none)
# ERROR: No matching distribution found for math

# %%
import math
from math import *

# %%
# Exerc 1
X=1
Y= 2.3
Z= X + Y
print(x, type(X),type(Y),type(Z))
print(Z)
