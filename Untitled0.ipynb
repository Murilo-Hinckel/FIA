# %% [markdown]
# <a href="https://colab.research.google.com/github/Murilo-Hinckel/FIA/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print( "Good bye world")
# Out:
# Good bye world

# %%
def createPrint():
  print(" Olá")

for i in range(9,1,1):
  createPrint
